# %% [markdown]
# # Finding optimal number of topics
# Machinelearingplus.com approach to finding the optimal number of topics is to build many LDA models with different values of number of topics (k) and pick the one that gives the highest coherence value.
#
# Choosing a ‘k’ that marks the end of a rapid growth of topic coherence usually offers meaningful and interpretable topics. Picking an even higher value can sometimes provide more granular sub-topics.
#
# If you see the same keywords being repeated in multiple topics, it’s probably a sign that the ‘k’ is too large.
#
# The compute_coherence_values() (see below) trains multiple LDA models and provides the models and their corresponding coherence scores.
#
# ## How it works
# 1. Reads the corpus, dictionary and M1 from the folder /model
# 2. Computes coherence values for an increasing number of topics
# 3. Prints the coherence values
# 4. Graphs the coherence values

# %%
import nltk
import gensim
import re
import pickle
from gensim import corpora
from gensim.parsing.preprocessing import *
from gensim.models import CoherenceModel
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
import pyLDAvis.gensim
import numpy as np
import os
from pprint import pprint

# Figures
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# Time
import time

import gensim
import pyLDAvis.gensim

import pandas as pd

import os
# For MAC OS
mallet_path = 'mallet-2.0.8/bin/mallet'
os.environ['MALLET_HOME'] = 'mallet-2.0.8'

# For Windows OS
#os.environ['MALLET_HOME'] = 'C:\\mallet'
#mallet_path = 'C:\\mallet\\bin\\mallet.bat'

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import pickle

def openFile(filename):
    file = open(filename,'rb')
    data = pickle.load(file)
    file.close()
    print(filename, 'read.')
    return data

dictionary = openFile('model/dictionaryData')
M1 = openFile('model/M1Data')
corpus = openFile('model/corpusData')
# Out:
# model/dictionaryData read.
# model/M1Data read.
# model/corpusData read.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start, step, random_seed_start, random_seed_limit):
    
    if random_seed_start != random_seed_limit:
        random_seed_range = range(random_seed_start, random_seed_limit)
        print('Now computing coherence values from', start, 'to', limit-1, 'with a step length of', step, 'for random seeds from', random_seed_start, 'to', random_seed_limit-1)
    else:
        random_seed_range = [random_seed_start]
        print('Now computing coherence values from', start, 'to', limit-1, 'with a step length of', step, 'for random seed', random_seed_start)

    print('------------------------------------------------------------------------------------------------')
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics
    start : First num of topics
    step : Step length when iterating num of topics
    random_seed_start : First random seed to iterate from
    random_seed_limit : Last random seed to iterate to (set to =random_seed_start if you want it fixed)

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    
    for num_topics in range(start, limit, step):
        for random_seed in random_seed_range:
            t0 = time.time()
            model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=dictionary, random_seed=random_seed)
            model_list.append(model)
            coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
            c_v = coherencemodel.get_coherence()
            coherence_values.append(c_v)
            t = time.time() - t0

            print('Coherence with', num_topics, 'topics and random state', random_seed ,'is now computed. Result was:', c_v, 'and it took', round(t,1), 'seconds.')
    print('------------------------------------------------------------------------------------------------')
    print('Done!')
    return model_list, coherence_values

# %%
def coherencePlot(start, limit, step, c_v, figure):
    x = range(start, limit, step)
    xi = [*x]
    
    plt.plot(x, c_v)
    plt.xlabel("Num Topics")
    plt.ylabel("Coherence score")
    plt.xticks(xi, x)
    plt.legend(("coherence_values"), loc='best')
    plt.grid(True)
    plt.show()
    
    figure.savefig('plots/' + str(start) + '-' + str(limit) + '.pdf')

# %%
def coherencePlotWithRandomState(start, limit, rs_start, rs_limit, step, c_v, figure):
    x_label = []
    x_index = []
    
    for i in range(start, limit):
        for j in range(rs_start1, rs_limit1):
            x_label.append('(' + str(i) + ',' + str(j) + ')')
            
    for k in range (0, (limit-start)*(rs_limit-rs_start)):
        x_index.append(k)
    
    plt.plot(x_label, c_v)
    plt.xlabel("(Num Topics, Random State)")
    plt.ylabel("Coherence score")
    plt.xticks(x_index, x_label)
    plt.legend(("coherence_values"), loc='best')
    plt.grid(True)
    plt.show()
    
    figure.savefig('plots/' + str(start) + '-' + str(limit) + '_' + str(rs_start) + '-' + str(rs_limit) + '.pdf')

# %%
def coherencePlotWithRandomStateMultiLines(start, limit, rs_start, rs_limit, step, c_v, figure):
    x_index = []
    index = start
    
    for i in range(rs_start, rs_limit):
        coherence = []
        x_label = []
        for j in range(start, limit):
            x_label.append(j)
            coherence.append(c_v[index])
            x_index.append(index)
            index += 1
        
        plt.plot(x_label, coherence)
    
    plt.plot(x_label, c_v)
    plt.xlabel("(Num Topics, Random State)")
    plt.ylabel("Coherence score")
    plt.xticks(x_index, x_label)
    plt.legend(("coherence_values"), loc='best')
    plt.grid(True)
    plt.show()
    
    figure.savefig('plots/' + str(start) + '-' + str(limit) + '_' + str(rs_start) + '-' + str(rs_limit) + '.pdf')

# %%
# Plot the graph and save it in /plots folder

f = plt.figure(figsize=(10, 6), dpi=80)
coherencePlotWithRandomStateMultiLines(start1, limit1, rs_start1, rs_limit1, step1, coherence_values1, f)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-53a7ac9d8552> in <module>
#       2
#       3 f = plt.figure(figsize=(10, 6), dpi=80)
# ----> 4 coherencePlotWithRandomStateMultiLines(start1, limit1, rs_start1, rs_limit1, step1, coherence_values1, f)
#
# <ipython-input-57-88a3df7f21c5> in coherencePlotWithRandomStateMultiLines(start, limit, rs_start, rs_limit, step, c_v, figure)
#       8         for j in range(start, limit):
#       9             x_label.append(j)
# ---> 10             coherence.append(c_v[index])
#      11             x_index.append(index)
#      12             index += 1
#
# IndexError: list index out of range

# %% [markdown]
# ## Coherence score over topics, Stepping every 4th
# Stepping from `start3` to `limit3` with a step length of `step3` and random state variable `random_state3`

# %% [raw]
# # Coherence values calculated 2021-05-04 11:31 on 5427 documents. Result was:
#
# coherence_values3 = [0.31889131990220865, 0.4174271188508795, 0.47042567411518854, 0.453798822216873, 0.4644554004411594, 0.45549889787263104, 0.45835987222938024, 0.4572095565787076, 0.4226022422849424, 0.43955242106630704, 0.4366190433521844, 0.4399333804813252, 0.43721961128467496, 0.4322080883065282, 0.42000399418477, 0.42274137332804906, 0.4135154810904364, 0.4101520468075474, 0.4086828256545025, 0.41081618886045335, 0.40495044168523786, 0.40945962872792685, 0.4058833601406915, 0.4013737298813306, 0.39775047763496846]

# %%
start3 = 2
limit3 = 100
step3 = 4

random_state3 = 4

# %%
# Can take a long time to run

model_list, coherence_values3 = compute_coherence_values(dictionary=dictionary, corpus=M1, texts=corpus, limit=limit3, start=start3, step=step3, random_seed_start=random_state3, random_seed_limit=random_state3)
# Out:
# Now computing coherence values from 2 to 99 with a step length of 4 for random seed 4
# ------------------------------------------------------------------------------------------------
# Coherence with 2 topics and random state 4 is now computed. Result was: 0.33245401307370975 and it took 49.7 seconds.
# Coherence with 6 topics and random state 4 is now computed. Result was: 0.45290606522444293 and it took 49.0 seconds.
# Coherence with 10 topics and random state 4 is now computed. Result was: 0.45687951073639477 and it took 51.7 seconds.
# Coherence with 14 topics and random state 4 is now computed. Result was: 0.4972044502388814 and it took 52.1 seconds.
# Coherence with 18 topics and random state 4 is now computed. Result was: 0.46305870072918637 and it took 52.7 seconds.
# Coherence with 22 topics and random state 4 is now computed. Result was: 0.44701270321044734 and it took 54.2 seconds.
# Coherence with 26 topics and random state 4 is now computed. Result was: 0.46603437456958974 and it took 55.1 seconds.
# Coherence with 30 topics and random state 4 is now computed. Result was: 0.4434469590672661 and it took 56.5 seconds.
# Coherence with 34 topics and random state 4 is now computed. Result was: 0.438426071079072 and it took 60.1 seconds.
# Coherence with 38 topics and random state 4 is now computed. Result was: 0.44336473459007975 and it took 55.7 seconds.
# Coherence with 42 topics and random state 4 is now computed. Result was: 0.4392790853863096 and it took 60.0 seconds.
# Coherence with 46 topics and random state 4 is now computed. Result was: 0.42410609135738675 and it took 60.5 seconds.
# Coherence with 50 topics and random state 4 is now computed. Result was: 0.4380325027612891 and it took 61.7 seconds.
# Coherence with 54 topics and random state 4 is now computed. Result was: 0.41862237656024526 and it took 62.4 seconds.
# Coherence with 58 topics and random state 4 is now computed. Result was: 0.4312498585338452 and it took 64.7 seconds.
# Coherence with 62 topics and random state 4 is now computed. Result was: 0.4261738215772045 and it took 65.5 seconds.
# Coherence with 66 topics and random state 4 is now computed. Result was: 0.4274745753427075 and it took 65.8 seconds.
# Coherence with 70 topics and random state 4 is now computed. Result was: 0.41871224061975204 and it took 65.0 seconds.
# Coherence with 74 topics and random state 4 is now computed. Result was: 0.4042141547305698 and it took 66.6 seconds.
# Coherence with 78 topics and random state 4 is now computed. Result was: 0.4123957577948921 and it took 66.9 seconds.
# Coherence with 82 topics and random state 4 is now computed. Result was: 0.41749221207216053 and it took 69.8 seconds.
# Coherence with 86 topics and random state 4 is now computed. Result was: 0.4080826494782624 and it took 69.6 seconds.
# Coherence with 90 topics and random state 4 is now computed. Result was: 0.392260506667788 and it took 72.8 seconds.
# Coherence with 94 topics and random state 4 is now computed. Result was: 0.41178384603407914 and it took 68.1 seconds.
# Coherence with 98 topics and random state 4 is now computed. Result was: 0.3927254390574449 and it took 69.1 seconds.
# ------------------------------------------------------------------------------------------------
# Done!

# %%
# Save to pandas table to make graphing easier

# Save the years and conferences in a Panda table
#df_coherence_values3 = pd.DataFrame(np.column_stack((yearList, conferenceList)), columns=['Year', 'Conf'])
#df_coherence_values3 = pd.DataFrame(coherence_values3, columns=['Coherence'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e0f378b106e3> in <module>
#       3 # Save the years and conferences in a Panda table
#       4 #df_coherence_values3 = pd.DataFrame(np.column_stack((yearList, conferenceList)), columns=['Year', 'Conf'])
# ----> 5 df_coherence_values3 = pd.DataFrame(coherence_values3, columns=['Coherence'])
#
# NameError: name 'pd' is not defined

# %%
# Print the coherence scores and save to pandas table
nrTopics_randomState3 = []
df_coherence_values3 = pd.DataFrame(columns=['Num_Topics', 'Random_Variable', 'Coherence_Score'])

for m, cv in zip(range(start3, limit3, step3), coherence_values3):
    # create new row
    new_row = {'Num_Topics':m, 'Random_Variable':random_state3, 'Coherence_Score':cv}
    #append row to the dataframe
    df_coherence_values3 = df_coherence_values3.append(new_row, ignore_index=True)
    
    # used to calculate highest coherence
    nrTopics_randomState3.append('nrTopics: ' + str(m) + ', randomState: ' + str(random_state3))
# print coherence table
df_coherence_values3
# Out:
# {'Num_Topics': 2, 'Random_Variable': 4, 'Coherence_Score': 0.33245401307370975}
# {'Num_Topics': 6, 'Random_Variable': 4, 'Coherence_Score': 0.45290606522444293}
# {'Num_Topics': 10, 'Random_Variable': 4, 'Coherence_Score': 0.45687951073639477}
# {'Num_Topics': 14, 'Random_Variable': 4, 'Coherence_Score': 0.4972044502388814}
# {'Num_Topics': 18, 'Random_Variable': 4, 'Coherence_Score': 0.46305870072918637}
# {'Num_Topics': 22, 'Random_Variable': 4, 'Coherence_Score': 0.44701270321044734}
# {'Num_Topics': 26, 'Random_Variable': 4, 'Coherence_Score': 0.46603437456958974}
# {'Num_Topics': 30, 'Random_Variable': 4, 'Coherence_Score': 0.4434469590672661}
# {'Num_Topics': 34, 'Random_Variable': 4, 'Coherence_Score': 0.438426071079072}
# {'Num_Topics': 38, 'Random_Variable': 4, 'Coherence_Score': 0.44336473459007975}
# {'Num_Topics': 42, 'Random_Variable': 4, 'Coherence_Score': 0.4392790853863096}
# {'Num_Topics': 46, 'Random_Variable': 4, 'Coherence_Score': 0.42410609135738675}
# {'Num_Topics': 50, 'Random_Variable': 4, 'Coherence_Score': 0.4380325027612891}
# {'Num_Topics': 54, 'Random_Variable': 4, 'Coherence_Score': 0.41862237656024526}
# {'Num_Topics': 58, 'Random_Variable': 4, 'Coherence_Score': 0.4312498585338452}
# {'Num_Topics': 62, 'Random_Variable': 4, 'Coherence_Score': 0.4261738215772045}
# {'Num_Topics': 66, 'Random_Variable': 4, 'Coherence_Score': 0.4274745753427075}
# {'Num_Topics': 70, 'Random_Variable': 4, 'Coherence_Score': 0.41871224061975204}
# {'Num_Topics': 74, 'Random_Variable': 4, 'Coherence_Score': 0.4042141547305698}
# {'Num_Topics': 78, 'Random_Variable': 4, 'Coherence_Score': 0.4123957577948921}
# {'Num_Topics': 82, 'Random_Variable': 4, 'Coherence_Score': 0.41749221207216053}
# {'Num_Topics': 86, 'Random_Variable': 4, 'Coherence_Score': 0.4080826494782624}
# {'Num_Topics': 90, 'Random_Variable': 4, 'Coherence_Score': 0.392260506667788}
# {'Num_Topics': 94, 'Random_Variable': 4, 'Coherence_Score': 0.41178384603407914}
# {'Num_Topics': 98, 'Random_Variable': 4, 'Coherence_Score': 0.3927254390574449}
#     Num_Topics  Random_Variable  Coherence_Score
# 0          2.0              4.0         0.332454
# 1          6.0              4.0         0.452906
# 2         10.0              4.0         0.456880
# 3         14.0              4.0         0.497204
# 4         18.0              4.0         0.463059
# 5         22.0              4.0         0.447013
# 6         26.0              4.0         0.466034
# 7         30.0              4.0         0.443447
# 8         34.0              4.0         0.438426
# 9         38.0              4.0         0.443365
# 10        42.0              4.0         0.439279
# 11        46.0              4.0         0.424106
# 12        50.0              4.0         0.438033
# 13        54.0              4.0         0.418622
# 14        58.0              4.0         0.431250
# 15        62.0              4.0         0.426174
# 16        66.0              4.0         0.427475
# 17        70.0              4.0         0.418712
# 18        74.0              4.0         0.404214
# 19        78.0              4.0         0.412396
# 20        82.0              4.0         0.417492
# 21        86.0              4.0         0.408083
# 22        90.0              4.0         0.392261
# 23        94.0              4.0         0.411784
# 24        98.0              4.0         0.392725

# %%
f = plt.figure(figsize=(22, 6), dpi=80)

coherencePlot(start3, limit3, step3, coherence_values3, f)

# %% [markdown]
# ### Result
# This gives us the 5 highest coherence values:

# %%
# Print top 5 best coherence values
i=1
for cv, name in sorted(zip(coherence_values3, nrTopics_randomState3), reverse=True)[:5]:
    print(str(i) + '. Coherence score:', round(cv, 3), name)
    i+=1
# Out:
# 1. Coherence score: 0.497 nrTopics: 14, randomState: 4
# 2. Coherence score: 0.466 nrTopics: 26, randomState: 4
# 3. Coherence score: 0.463 nrTopics: 18, randomState: 4
# 4. Coherence score: 0.457 nrTopics: 10, randomState: 4
# 5. Coherence score: 0.453 nrTopics: 6, randomState: 4

# %% [markdown]
# ## Coherence score over topics and random state
# Stepping number of topics from `start1` to `limit1` with a step length of `step1`
#
# and Stepping random state from `rs_start1` to `rs_limit1`

# %% [raw]
# # Coherence values calculated 2021-05-04 21:30 for number of topics from 5 to 14 with a step length of 1 for random seeds from 1 to 5on 5427 documents. Result was:
#
# coherence_values1 = [0.43029221607745133, 0.425596948089028, 0.4442251149399706, 0.42584057457826185, 0.4494967001243541, 0.42329814588982523, 0.4378250694518622, 0.45154804749332667, 0.45290606522444293, 0.4494596021613138, 0.443828639463137, 0.45340743299498387, 0.4406807792805985, 0.45846663080517563, 0.4653815591844042, 0.45008578062825466, 0.463269521426835, 0.4490302910166142, 0.4392082168420458, 0.4403236447470217, 0.47083731870286016, 0.45863127819744925, 0.45193289699711037, 0.4759659234919878, 0.4466670069258447, 0.43555948038026593, 0.4602207336836958, 0.47262616678776376, 0.45687951073639477, 0.45425422663258264, 0.43617929822778884, 0.4655757056765676, 0.4627710797589551, 0.4665403422224727, 0.4503655678363053, 0.4465786299032745, 0.44706683687435245, 0.45374280378020554, 0.4411174679894065, 0.45155108069921207, 0.4546427160232363, 0.46525147744437617, 0.4502018534914915, 0.4913226830455449, 0.45446301930269856, 0.4446556359226682, 0.4408315125387397, 0.46912893799926136, 0.4972044502388814, 0.4639763697607874]

# %%
start1 = 10
limit1 = 31
step1 = 1

rs_start1 = 1
rs_limit1 = 11

# %%
# Can take a long time to run

model_list, coherence_values1 = compute_coherence_values(dictionary=dictionary, corpus=M1, texts=corpus, limit=limit1, start=start1, step=step1, random_seed_start=rs_start1, random_seed_limit=rs_limit1)
# Out:
# Now computing coherence values from 10 to 30 with a step length of 1 for random seeds from 1 to 10
# ------------------------------------------------------------------------------------------------
# Coherence with 10 topics and random state 1 is now computed. Result was: 0.43555948038026593 and it took 51.1 seconds.
# Coherence with 10 topics and random state 2 is now computed. Result was: 0.4602207336836958 and it took 50.6 seconds.
# Coherence with 10 topics and random state 3 is now computed. Result was: 0.47262616678776376 and it took 50.2 seconds.
# Coherence with 10 topics and random state 4 is now computed. Result was: 0.45687951073639477 and it took 50.0 seconds.
# Coherence with 10 topics and random state 5 is now computed. Result was: 0.45425422663258264 and it took 50.9 seconds.
# Coherence with 10 topics and random state 6 is now computed. Result was: 0.4651870235590444 and it took 49.9 seconds.
# Coherence with 10 topics and random state 7 is now computed. Result was: 0.4717738069116441 and it took 49.9 seconds.
# Coherence with 10 topics and random state 8 is now computed. Result was: 0.45191760773131034 and it took 50.7 seconds.
# Coherence with 10 topics and random state 9 is now computed. Result was: 0.4708935690331284 and it took 50.9 seconds.
# Coherence with 10 topics and random state 10 is now computed. Result was: 0.4287226350641678 and it took 51.1 seconds.
# Coherence with 11 topics and random state 1 is now computed. Result was: 0.43617929822778884 and it took 51.0 seconds.
# Coherence with 11 topics and random state 2 is now computed. Result was: 0.4655757056765676 and it took 50.2 seconds.
# Coherence with 11 topics and random state 3 is now computed. Result was: 0.4627710797589551 and it took 50.4 seconds.
# Coherence with 11 topics and random state 4 is now computed. Result was: 0.4665403422224727 and it took 51.6 seconds.
# Coherence with 11 topics and random state 5 is now computed. Result was: 0.4503655678363053 and it took 51.0 seconds.
# Coherence with 11 topics and random state 6 is now computed. Result was: 0.46419499095583916 and it took 50.6 seconds.
# Coherence with 11 topics and random state 7 is now computed. Result was: 0.45724276733469327 and it took 51.8 seconds.
# Coherence with 11 topics and random state 8 is now computed. Result was: 0.457692401411032 and it took 51.3 seconds.
# Coherence with 11 topics and random state 9 is now computed. Result was: 0.4651346151753291 and it took 50.5 seconds.
# Coherence with 11 topics and random state 10 is now computed. Result was: 0.44718676650972883 and it took 51.7 seconds.
# Coherence with 12 topics and random state 1 is now computed. Result was: 0.4465786299032745 and it took 50.3 seconds.
# Coherence with 12 topics and random state 2 is now computed. Result was: 0.44706683687435245 and it took 50.9 seconds.
# Coherence with 12 topics and random state 3 is now computed. Result was: 0.45374280378020554 and it took 52.1 seconds.
# Coherence with 12 topics and random state 4 is now computed. Result was: 0.4411174679894065 and it took 50.7 seconds.
# Coherence with 12 topics and random state 5 is now computed. Result was: 0.45155108069921207 and it took 51.2 seconds.
# Coherence with 12 topics and random state 6 is now computed. Result was: 0.46826369284394304 and it took 51.6 seconds.
# Coherence with 12 topics and random state 7 is now computed. Result was: 0.4476012315322127 and it took 50.8 seconds.
# Coherence with 12 topics and random state 8 is now computed. Result was: 0.44152241116412677 and it took 50.7 seconds.
# Coherence with 12 topics and random state 9 is now computed. Result was: 0.4630203093784953 and it took 52.4 seconds.
# Coherence with 12 topics and random state 10 is now computed. Result was: 0.4320932328784269 and it took 51.3 seconds.
# Coherence with 13 topics and random state 1 is now computed. Result was: 0.4546427160232363 and it took 50.9 seconds.
# Coherence with 13 topics and random state 2 is now computed. Result was: 0.46525147744437617 and it took 51.1 seconds.
# Coherence with 13 topics and random state 3 is now computed. Result was: 0.4502018534914915 and it took 51.6 seconds.
# Coherence with 13 topics and random state 4 is now computed. Result was: 0.4913226830455449 and it took 51.1 seconds.
# Coherence with 13 topics and random state 5 is now computed. Result was: 0.45446301930269856 and it took 51.3 seconds.
# Coherence with 13 topics and random state 6 is now computed. Result was: 0.4396893040464644 and it took 51.6 seconds.
# Coherence with 13 topics and random state 7 is now computed. Result was: 0.4570553800144515 and it took 52.3 seconds.
# Coherence with 13 topics and random state 8 is now computed. Result was: 0.47445405968784926 and it took 51.3 seconds.
# Coherence with 13 topics and random state 9 is now computed. Result was: 0.47359528494769837 and it took 51.4 seconds.
# Coherence with 13 topics and random state 10 is now computed. Result was: 0.4821824818911464 and it took 51.4 seconds.
# Coherence with 14 topics and random state 1 is now computed. Result was: 0.4446556359226682 and it took 51.4 seconds.
# Coherence with 14 topics and random state 2 is now computed. Result was: 0.4408315125387397 and it took 50.9 seconds.
# Coherence with 14 topics and random state 3 is now computed. Result was: 0.46912893799926136 and it took 51.5 seconds.
# Coherence with 14 topics and random state 4 is now computed. Result was: 0.4972044502388814 and it took 51.4 seconds.
# Coherence with 14 topics and random state 5 is now computed. Result was: 0.4639763697607874 and it took 51.1 seconds.
# Coherence with 14 topics and random state 6 is now computed. Result was: 0.46089599212288324 and it took 51.1 seconds.
# Coherence with 14 topics and random state 7 is now computed. Result was: 0.47077580994784146 and it took 51.8 seconds.
# Coherence with 14 topics and random state 8 is now computed. Result was: 0.474313754192731 and it took 52.4 seconds.
# Coherence with 14 topics and random state 9 is now computed. Result was: 0.46888085787842193 and it took 52.2 seconds.
# Coherence with 14 topics and random state 10 is now computed. Result was: 0.47359162767275115 and it took 52.3 seconds.
# Coherence with 15 topics and random state 1 is now computed. Result was: 0.4765845001268509 and it took 52.2 seconds.
# Coherence with 15 topics and random state 2 is now computed. Result was: 0.48595584715495405 and it took 51.9 seconds.
# Coherence with 15 topics and random state 3 is now computed. Result was: 0.4633194285398726 and it took 52.1 seconds.
# Coherence with 15 topics and random state 4 is now computed. Result was: 0.4639053010306643 and it took 51.7 seconds.
# Coherence with 15 topics and random state 5 is now computed. Result was: 0.4587308213648182 and it took 51.2 seconds.
# Coherence with 15 topics and random state 6 is now computed. Result was: 0.45361609651316304 and it took 51.8 seconds.
# Coherence with 15 topics and random state 7 is now computed. Result was: 0.4810481916949908 and it took 52.2 seconds.
# Coherence with 15 topics and random state 8 is now computed. Result was: 0.4471326366028742 and it took 52.2 seconds.
# Coherence with 15 topics and random state 9 is now computed. Result was: 0.4426368889199153 and it took 51.7 seconds.
# Coherence with 15 topics and random state 10 is now computed. Result was: 0.4405980688098348 and it took 51.8 seconds.
# Coherence with 16 topics and random state 1 is now computed. Result was: 0.46879352626060905 and it took 52.2 seconds.
# Coherence with 16 topics and random state 2 is now computed. Result was: 0.45158182880012376 and it took 51.4 seconds.
# Coherence with 16 topics and random state 3 is now computed. Result was: 0.4609727016993512 and it took 52.7 seconds.
# Coherence with 16 topics and random state 4 is now computed. Result was: 0.46595575747873774 and it took 52.4 seconds.
# Coherence with 16 topics and random state 5 is now computed. Result was: 0.4679749383349461 and it took 52.2 seconds.
# Coherence with 16 topics and random state 6 is now computed. Result was: 0.4632868712081792 and it took 52.1 seconds.
# Coherence with 16 topics and random state 7 is now computed. Result was: 0.4629082943860869 and it took 52.5 seconds.
# Coherence with 16 topics and random state 8 is now computed. Result was: 0.42851217775690054 and it took 50.9 seconds.
# Coherence with 16 topics and random state 9 is now computed. Result was: 0.47801541143169457 and it took 51.7 seconds.
# Coherence with 16 topics and random state 10 is now computed. Result was: 0.4543537960024596 and it took 52.8 seconds.
# Coherence with 17 topics and random state 1 is now computed. Result was: 0.4464849328970814 and it took 53.1 seconds.
# Coherence with 17 topics and random state 2 is now computed. Result was: 0.4566187139306132 and it took 53.0 seconds.
# Coherence with 17 topics and random state 3 is now computed. Result was: 0.47298049565854705 and it took 52.8 seconds.
# Coherence with 17 topics and random state 4 is now computed. Result was: 0.457897029571285 and it took 52.5 seconds.
# Coherence with 17 topics and random state 5 is now computed. Result was: 0.4614563545398005 and it took 52.6 seconds.
# Coherence with 17 topics and random state 6 is now computed. Result was: 0.4589461675167128 and it took 52.2 seconds.
# Coherence with 17 topics and random state 7 is now computed. Result was: 0.47526918725711426 and it took 52.4 seconds.
# Coherence with 17 topics and random state 8 is now computed. Result was: 0.47550537893921585 and it took 52.5 seconds.
# Coherence with 17 topics and random state 9 is now computed. Result was: 0.4658735721442624 and it took 52.8 seconds.
# Coherence with 17 topics and random state 10 is now computed. Result was: 0.4836638887464639 and it took 53.9 seconds.
# Coherence with 18 topics and random state 1 is now computed. Result was: 0.46812813166225925 and it took 53.0 seconds.
# Coherence with 18 topics and random state 2 is now computed. Result was: 0.45113384811068147 and it took 53.2 seconds.
# Coherence with 18 topics and random state 3 is now computed. Result was: 0.446527993093547 and it took 53.0 seconds.
# Coherence with 18 topics and random state 4 is now computed. Result was: 0.46305870072918637 and it took 53.1 seconds.
# Coherence with 18 topics and random state 5 is now computed. Result was: 0.4709584639547652 and it took 52.5 seconds.
# Coherence with 18 topics and random state 6 is now computed. Result was: 0.46967497560626725 and it took 52.8 seconds.
# Coherence with 18 topics and random state 7 is now computed. Result was: 0.4781629954954148 and it took 53.3 seconds.
# Coherence with 18 topics and random state 8 is now computed. Result was: 0.4723939728907704 and it took 52.8 seconds.
# Coherence with 18 topics and random state 9 is now computed. Result was: 0.4579815025141113 and it took 52.7 seconds.
# Coherence with 18 topics and random state 10 is now computed. Result was: 0.4598706260310107 and it took 53.0 seconds.
# Coherence with 19 topics and random state 1 is now computed. Result was: 0.4571809929517905 and it took 53.5 seconds.
# Coherence with 19 topics and random state 2 is now computed. Result was: 0.4641624497708612 and it took 53.4 seconds.
# Coherence with 19 topics and random state 3 is now computed. Result was: 0.4527108102928654 and it took 54.2 seconds.
# Coherence with 19 topics and random state 4 is now computed. Result was: 0.45902943816166936 and it took 53.2 seconds.
# Coherence with 19 topics and random state 5 is now computed. Result was: 0.4653636925764144 and it took 52.8 seconds.
# Coherence with 19 topics and random state 6 is now computed. Result was: 0.44216629541133534 and it took 53.5 seconds.
# Coherence with 19 topics and random state 7 is now computed. Result was: 0.4546013112901559 and it took 53.9 seconds.
# Coherence with 19 topics and random state 8 is now computed. Result was: 0.4732849062725114 and it took 55.8 seconds.
# Coherence with 19 topics and random state 9 is now computed. Result was: 0.461788644076009 and it took 53.2 seconds.
# Coherence with 19 topics and random state 10 is now computed. Result was: 0.47048142245654967 and it took 52.7 seconds.
# Coherence with 20 topics and random state 1 is now computed. Result was: 0.4857673701858237 and it took 52.7 seconds.
# Coherence with 20 topics and random state 2 is now computed. Result was: 0.45822112236867696 and it took 52.4 seconds.
# Coherence with 20 topics and random state 3 is now computed. Result was: 0.46387949131056344 and it took 52.7 seconds.
# Coherence with 20 topics and random state 4 is now computed. Result was: 0.45681718386903825 and it took 52.9 seconds.
# Coherence with 20 topics and random state 5 is now computed. Result was: 0.4661829289990919 and it took 54.5 seconds.
# Coherence with 20 topics and random state 6 is now computed. Result was: 0.4680903439726826 and it took 57.7 seconds.
# Coherence with 20 topics and random state 7 is now computed. Result was: 0.47993142348474044 and it took 57.8 seconds.
# Coherence with 20 topics and random state 8 is now computed. Result was: 0.45831537888090323 and it took 57.8 seconds.
# Coherence with 20 topics and random state 9 is now computed. Result was: 0.46370469841324635 and it took 58.1 seconds.
# Coherence with 20 topics and random state 10 is now computed. Result was: 0.47200564608866874 and it took 57.5 seconds.
# Coherence with 21 topics and random state 1 is now computed. Result was: 0.47224328083596956 and it took 58.7 seconds.
# Coherence with 21 topics and random state 2 is now computed. Result was: 0.4729349213802919 and it took 53.8 seconds.
# Coherence with 21 topics and random state 3 is now computed. Result was: 0.43979417434874996 and it took 53.0 seconds.
# Coherence with 21 topics and random state 4 is now computed. Result was: 0.45354798058599155 and it took 53.1 seconds.
# Coherence with 21 topics and random state 5 is now computed. Result was: 0.4674453773047308 and it took 53.2 seconds.
# Coherence with 21 topics and random state 6 is now computed. Result was: 0.4771766665846111 and it took 53.4 seconds.
# Coherence with 21 topics and random state 7 is now computed. Result was: 0.43750882626839527 and it took 56.1 seconds.
# Coherence with 21 topics and random state 8 is now computed. Result was: 0.46467012289353804 and it took 53.5 seconds.
# Coherence with 21 topics and random state 9 is now computed. Result was: 0.4701502237739847 and it took 53.1 seconds.
# Coherence with 21 topics and random state 10 is now computed. Result was: 0.45162106887809456 and it took 55.7 seconds.
# Coherence with 22 topics and random state 1 is now computed. Result was: 0.45448909688027805 and it took 54.3 seconds.
# Coherence with 22 topics and random state 2 is now computed. Result was: 0.4406763982795759 and it took 53.6 seconds.
# Coherence with 22 topics and random state 3 is now computed. Result was: 0.45293256548333594 and it took 53.7 seconds.
# Coherence with 22 topics and random state 4 is now computed. Result was: 0.44701270321044734 and it took 53.9 seconds.
# Coherence with 22 topics and random state 5 is now computed. Result was: 0.44920256850257184 and it took 53.5 seconds.
# Coherence with 22 topics and random state 6 is now computed. Result was: 0.4498977747328814 and it took 53.5 seconds.
# Coherence with 22 topics and random state 7 is now computed. Result was: 0.47656001197267217 and it took 53.1 seconds.
# Coherence with 22 topics and random state 8 is now computed. Result was: 0.45831537962077534 and it took 53.6 seconds.
# Coherence with 22 topics and random state 9 is now computed. Result was: 0.4461594638902651 and it took 53.7 seconds.
# Coherence with 22 topics and random state 10 is now computed. Result was: 0.43450544822382664 and it took 53.8 seconds.
# Coherence with 23 topics and random state 1 is now computed. Result was: 0.4541506079751901 and it took 53.2 seconds.
# Coherence with 23 topics and random state 2 is now computed. Result was: 0.4637915243135164 and it took 53.6 seconds.
# Coherence with 23 topics and random state 3 is now computed. Result was: 0.4681047924214364 and it took 53.6 seconds.
# Coherence with 23 topics and random state 4 is now computed. Result was: 0.44578787491225286 and it took 52.5 seconds.
# Coherence with 23 topics and random state 5 is now computed. Result was: 0.4536147973491502 and it took 54.9 seconds.
# Coherence with 23 topics and random state 6 is now computed. Result was: 0.4817523472714159 and it took 53.8 seconds.
# Coherence with 23 topics and random state 7 is now computed. Result was: 0.4667636558497993 and it took 53.5 seconds.
# Coherence with 23 topics and random state 8 is now computed. Result was: 0.4567984321493412 and it took 53.2 seconds.
# Coherence with 23 topics and random state 9 is now computed. Result was: 0.4586879203270488 and it took 54.2 seconds.
# Coherence with 23 topics and random state 10 is now computed. Result was: 0.46609580226530445 and it took 53.8 seconds.
# Coherence with 24 topics and random state 1 is now computed. Result was: 0.459534450144866 and it took 54.4 seconds.
# Coherence with 24 topics and random state 2 is now computed. Result was: 0.470022571890418 and it took 53.9 seconds.
# Coherence with 24 topics and random state 3 is now computed. Result was: 0.4441038454459068 and it took 53.6 seconds.
# Coherence with 24 topics and random state 4 is now computed. Result was: 0.46507194864104545 and it took 54.0 seconds.
# Coherence with 24 topics and random state 5 is now computed. Result was: 0.4676075170053264 and it took 54.1 seconds.
# Coherence with 24 topics and random state 6 is now computed. Result was: 0.4499680419690284 and it took 53.9 seconds.
# Coherence with 24 topics and random state 7 is now computed. Result was: 0.4471192334952916 and it took 55.0 seconds.
# Coherence with 24 topics and random state 8 is now computed. Result was: 0.46104689621644496 and it took 59.1 seconds.
# Coherence with 24 topics and random state 9 is now computed. Result was: 0.45976346234790194 and it took 54.5 seconds.
# Coherence with 24 topics and random state 10 is now computed. Result was: 0.4616820763465512 and it took 53.8 seconds.
# Coherence with 25 topics and random state 1 is now computed. Result was: 0.4724531141456051 and it took 54.1 seconds.
# Coherence with 25 topics and random state 2 is now computed. Result was: 0.4498411744129902 and it took 53.7 seconds.
# Coherence with 25 topics and random state 3 is now computed. Result was: 0.4590349843803907 and it took 53.7 seconds.
# Coherence with 25 topics and random state 4 is now computed. Result was: 0.44743193623174704 and it took 54.1 seconds.
# Coherence with 25 topics and random state 5 is now computed. Result was: 0.45905565602056647 and it took 59.1 seconds.
# Coherence with 25 topics and random state 6 is now computed. Result was: 0.4603907714692198 and it took 59.1 seconds.
# Coherence with 25 topics and random state 7 is now computed. Result was: 0.4664084585286606 and it took 58.5 seconds.
# Coherence with 25 topics and random state 8 is now computed. Result was: 0.46238024196109945 and it took 58.7 seconds.
# Coherence with 25 topics and random state 9 is now computed. Result was: 0.4368082497122218 and it took 58.7 seconds.
# Coherence with 25 topics and random state 10 is now computed. Result was: 0.46089191015411834 and it took 57.6 seconds.
# Coherence with 26 topics and random state 1 is now computed. Result was: 0.4624984999278872 and it took 58.4 seconds.
# Coherence with 26 topics and random state 2 is now computed. Result was: 0.45210819958986254 and it took 59.0 seconds.
# Coherence with 26 topics and random state 3 is now computed. Result was: 0.46495270311434883 and it took 58.9 seconds.
# Coherence with 26 topics and random state 4 is now computed. Result was: 0.46603437456958974 and it took 59.0 seconds.
# Coherence with 26 topics and random state 5 is now computed. Result was: 0.46780151802493875 and it took 58.9 seconds.
# Coherence with 26 topics and random state 6 is now computed. Result was: 0.4680774271030469 and it took 58.7 seconds.
# Coherence with 26 topics and random state 7 is now computed. Result was: 0.4570702317258813 and it took 58.5 seconds.
# Coherence with 26 topics and random state 8 is now computed. Result was: 0.4577081994530831 and it took 59.0 seconds.
# Coherence with 26 topics and random state 9 is now computed. Result was: 0.45853625902551953 and it took 58.1 seconds.
# Coherence with 26 topics and random state 10 is now computed. Result was: 0.4421911262515727 and it took 55.6 seconds.
# Coherence with 27 topics and random state 1 is now computed. Result was: 0.4707628257242669 and it took 56.3 seconds.
# Coherence with 27 topics and random state 2 is now computed. Result was: 0.4573865128787577 and it took 54.8 seconds.
# Coherence with 27 topics and random state 3 is now computed. Result was: 0.45034152652047255 and it took 56.5 seconds.
# Coherence with 27 topics and random state 4 is now computed. Result was: 0.4578871424103622 and it took 55.3 seconds.
# Coherence with 27 topics and random state 5 is now computed. Result was: 0.4779054429101208 and it took 54.9 seconds.
# Coherence with 27 topics and random state 6 is now computed. Result was: 0.4478279468051746 and it took 54.8 seconds.
# Coherence with 27 topics and random state 7 is now computed. Result was: 0.46746338702921075 and it took 56.4 seconds.
# Coherence with 27 topics and random state 8 is now computed. Result was: 0.4659494790522177 and it took 55.0 seconds.
# Coherence with 27 topics and random state 9 is now computed. Result was: 0.4538367048759059 and it took 55.2 seconds.
# Coherence with 27 topics and random state 10 is now computed. Result was: 0.46532894232943933 and it took 55.2 seconds.
# Coherence with 28 topics and random state 1 is now computed. Result was: 0.46374554707510207 and it took 55.6 seconds.
# Coherence with 28 topics and random state 2 is now computed. Result was: 0.4495154126943794 and it took 54.7 seconds.
# Coherence with 28 topics and random state 3 is now computed. Result was: 0.4463541466873061 and it took 54.8 seconds.
# Coherence with 28 topics and random state 4 is now computed. Result was: 0.46116192104521214 and it took 54.4 seconds.
# Coherence with 28 topics and random state 5 is now computed. Result was: 0.4616287578866413 and it took 54.5 seconds.
# Coherence with 28 topics and random state 6 is now computed. Result was: 0.4596160292181657 and it took 54.0 seconds.
# Coherence with 28 topics and random state 7 is now computed. Result was: 0.44479185372609825 and it took 54.7 seconds.
# Coherence with 28 topics and random state 8 is now computed. Result was: 0.44186624590663975 and it took 59.4 seconds.
# Coherence with 28 topics and random state 9 is now computed. Result was: 0.4693330717258614 and it took 59.6 seconds.
# Coherence with 28 topics and random state 10 is now computed. Result was: 0.4633493835508964 and it took 54.4 seconds.
# Coherence with 29 topics and random state 1 is now computed. Result was: 0.4409466620695689 and it took 54.4 seconds.
# Coherence with 29 topics and random state 2 is now computed. Result was: 0.4479100964014288 and it took 54.7 seconds.
# Coherence with 29 topics and random state 3 is now computed. Result was: 0.44305559723926513 and it took 54.5 seconds.
# Coherence with 29 topics and random state 4 is now computed. Result was: 0.4502521382958451 and it took 54.8 seconds.
# Coherence with 29 topics and random state 5 is now computed. Result was: 0.46609603747573125 and it took 55.4 seconds.
# Coherence with 29 topics and random state 6 is now computed. Result was: 0.4433716118421555 and it took 55.5 seconds.
# Coherence with 29 topics and random state 7 is now computed. Result was: 0.4588154531747145 and it took 54.8 seconds.
# Coherence with 29 topics and random state 8 is now computed. Result was: 0.45534334950651667 and it took 55.0 seconds.
# Coherence with 29 topics and random state 9 is now computed. Result was: 0.42947619299207024 and it took 54.5 seconds.
# Coherence with 29 topics and random state 10 is now computed. Result was: 0.44892101105211263 and it took 55.2 seconds.
# Coherence with 30 topics and random state 1 is now computed. Result was: 0.4580133037649035 and it took 54.8 seconds.
# Coherence with 30 topics and random state 2 is now computed. Result was: 0.44870208197611905 and it took 55.2 seconds.
# Coherence with 30 topics and random state 3 is now computed. Result was: 0.4605716045816986 and it took 55.0 seconds.
# Coherence with 30 topics and random state 4 is now computed. Result was: 0.4434469590672661 and it took 55.0 seconds.
# Coherence with 30 topics and random state 5 is now computed. Result was: 0.4416954313046887 and it took 55.2 seconds.
# Coherence with 30 topics and random state 6 is now computed. Result was: 0.45141977286358076 and it took 55.5 seconds.
# Coherence with 30 topics and random state 7 is now computed. Result was: 0.4491421256822189 and it took 55.4 seconds.
# Coherence with 30 topics and random state 8 is now computed. Result was: 0.45851131664367023 and it took 55.4 seconds.
# Coherence with 30 topics and random state 9 is now computed. Result was: 0.45246123217992823 and it took 54.9 seconds.
# Coherence with 30 topics and random state 10 is now computed. Result was: 0.4417080257444112 and it took 60.0 seconds.
# ------------------------------------------------------------------------------------------------
# Done!

# %%
# Plot the graph and save it in /plots folder

f = plt.figure(figsize=(38, 6), dpi=80)
coherencePlotWithRandomState(start1, limit1, rs_start1, rs_limit1, step1, coherence_values1, f)

# %%
# Print the coherence scores
nrTopics_randomState = []

for m in range(start1, limit1, step1):
    for n, cv in zip(range(rs_start1, rs_limit1), coherence_values1):
        print("Num Topics =", m , "and Random Variable =", n , "has Coherence Value of", round(cv, 4))
        nrTopics_randomState.append('nrTopics: ' + str(m) + ', randomState: ' + str(n))
    print("--------------------------------------------------------------------")
# Out:
# Num Topics = 10 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 10 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 10 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 10 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 10 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 10 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 10 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 10 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 10 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 10 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 11 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 11 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 11 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 11 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 11 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 11 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 11 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 11 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 11 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 11 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 12 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 12 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 12 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 12 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 12 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 12 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 12 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 12 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 12 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 12 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 13 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 13 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 13 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 13 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 13 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 13 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 13 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 13 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 13 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 13 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 14 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 14 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 14 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 14 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 14 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 14 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 14 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 14 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 14 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 14 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 15 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 15 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 15 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 15 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 15 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 15 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 15 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 15 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 15 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 15 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 16 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 16 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 16 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 16 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 16 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 16 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 16 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 16 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 16 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 16 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 17 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 17 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 17 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 17 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 17 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 17 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 17 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 17 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 17 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 17 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 18 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 18 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 18 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 18 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 18 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 18 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 18 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 18 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 18 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 18 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 19 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 19 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 19 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 19 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 19 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 19 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 19 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 19 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 19 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 19 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 20 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 20 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 20 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 20 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 20 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 20 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 20 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 20 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 20 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 20 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 21 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 21 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 21 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 21 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 21 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 21 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 21 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 21 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 21 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 21 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 22 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 22 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 22 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 22 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 22 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 22 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 22 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 22 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 22 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 22 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 23 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 23 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 23 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 23 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 23 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 23 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 23 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 23 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 23 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 23 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 24 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 24 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 24 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 24 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 24 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 24 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 24 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 24 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 24 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 24 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 25 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 25 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 25 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 25 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 25 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 25 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 25 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 25 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 25 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 25 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 26 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 26 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 26 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 26 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 26 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 26 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 26 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 26 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 26 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 26 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 27 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 27 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 27 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 27 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 27 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 27 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 27 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 27 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 27 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 27 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 28 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 28 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 28 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 28 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 28 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 28 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 28 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 28 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 28 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 28 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 29 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 29 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 29 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 29 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 29 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 29 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 29 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 29 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 29 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 29 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------
# Num Topics = 30 and Random Variable = 1 has Coherence Value of 0.4356
# Num Topics = 30 and Random Variable = 2 has Coherence Value of 0.4602
# Num Topics = 30 and Random Variable = 3 has Coherence Value of 0.4726
# Num Topics = 30 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 30 and Random Variable = 5 has Coherence Value of 0.4543
# Num Topics = 30 and Random Variable = 6 has Coherence Value of 0.4652
# Num Topics = 30 and Random Variable = 7 has Coherence Value of 0.4718
# Num Topics = 30 and Random Variable = 8 has Coherence Value of 0.4519
# Num Topics = 30 and Random Variable = 9 has Coherence Value of 0.4709
# Num Topics = 30 and Random Variable = 10 has Coherence Value of 0.4287
# --------------------------------------------------------------------

# %% [markdown]
# ### Result
# This gives us the top 5 highest coherence scores:

# %%
# Print top 5 best coherence values
i=1
for cv, name in sorted(zip(coherence_values1, nrTopics_randomState), reverse=True)[:5]:
    print(str(i) + '. Coherence score:', round(cv, 3), name)
    i+=1
# Out:
# 1. Coherence score: 0.497 nrTopics: 14, randomState: 4
# 2. Coherence score: 0.491 nrTopics: 13, randomState: 4
# 3. Coherence score: 0.486 nrTopics: 15, randomState: 2
# 4. Coherence score: 0.486 nrTopics: 20, randomState: 1
# 5. Coherence score: 0.484 nrTopics: 17, randomState: 10

# %% [markdown]
# ## Coherence score over topics, Stepping every one
# Now we want to be more exact but since the coherence is dropping with higher number of topics we reduce the upper limit.
#
# Stepping from `start2` to `limit2` with a step length of `step2`

# %% [raw]
# # Coherence values calculated 2021-05-04 22:05 on 5427 documents. Result was:
#
# coherence_values2 = [0.4392082168420458, 0.4759659234919878, 0.45687951073639477, 0.4665403422224727, 0.4411174679894065, 0.4913226830455449, 0.4972044502388814, 0.4639053010306643, 0.46595575747873774, 0.457897029571285, 0.46305870072918637, 0.45902943816166936, 0.45681718386903825, 0.45354798058599155, 0.44701270321044734, 0.44578787491225286, 0.46507194864104545, 0.44743193623174704, 0.46603437456958974, 0.4578871424103622, 0.46116192104521214, 0.4502521382958451]

# %%
start2 = 8
limit2 = 30
step2 = 1

random_state2 = 4

# %%
# Can take a long time to run
model_list2, coherence_values2 = compute_coherence_values(dictionary=dictionary, corpus=M1, texts=corpus, limit=limit2, start=start2, step=step2, random_seed_start=random_state2, random_seed_limit=random_state2)
# Out:
# Now computing coherence values from 8 to 29 with a step length of 1 for random seed 4
# ------------------------------------------------------------------------------------------------
# Coherence with 8 topics and random state 4 is now computed. Result was: 0.4392082168420458 and it took 50.2 seconds.
# Coherence with 9 topics and random state 4 is now computed. Result was: 0.4759659234919878 and it took 50.1 seconds.
# Coherence with 10 topics and random state 4 is now computed. Result was: 0.45687951073639477 and it took 49.9 seconds.
# Coherence with 11 topics and random state 4 is now computed. Result was: 0.4665403422224727 and it took 50.6 seconds.
# Coherence with 12 topics and random state 4 is now computed. Result was: 0.4411174679894065 and it took 50.3 seconds.
# Coherence with 13 topics and random state 4 is now computed. Result was: 0.4913226830455449 and it took 51.1 seconds.
# Coherence with 14 topics and random state 4 is now computed. Result was: 0.4972044502388814 and it took 51.5 seconds.
# Coherence with 15 topics and random state 4 is now computed. Result was: 0.4639053010306643 and it took 51.6 seconds.
# Coherence with 16 topics and random state 4 is now computed. Result was: 0.46595575747873774 and it took 51.8 seconds.
# Coherence with 17 topics and random state 4 is now computed. Result was: 0.457897029571285 and it took 55.8 seconds.
# Coherence with 18 topics and random state 4 is now computed. Result was: 0.46305870072918637 and it took 57.1 seconds.
# Coherence with 19 topics and random state 4 is now computed. Result was: 0.45902943816166936 and it took 57.8 seconds.
# Coherence with 20 topics and random state 4 is now computed. Result was: 0.45681718386903825 and it took 57.6 seconds.
# Coherence with 21 topics and random state 4 is now computed. Result was: 0.45354798058599155 and it took 57.5 seconds.
# Coherence with 22 topics and random state 4 is now computed. Result was: 0.44701270321044734 and it took 57.9 seconds.
# Coherence with 23 topics and random state 4 is now computed. Result was: 0.44578787491225286 and it took 58.2 seconds.
# Coherence with 24 topics and random state 4 is now computed. Result was: 0.46507194864104545 and it took 58.5 seconds.
# Coherence with 25 topics and random state 4 is now computed. Result was: 0.44743193623174704 and it took 58.9 seconds.
# Coherence with 26 topics and random state 4 is now computed. Result was: 0.46603437456958974 and it took 58.8 seconds.
# Coherence with 27 topics and random state 4 is now computed. Result was: 0.4578871424103622 and it took 59.2 seconds.
# Coherence with 28 topics and random state 4 is now computed. Result was: 0.46116192104521214 and it took 59.1 seconds.
# Coherence with 29 topics and random state 4 is now computed. Result was: 0.4502521382958451 and it took 60.1 seconds.
# ------------------------------------------------------------------------------------------------
# Done!

# %%
# Print the coherence scores
nrTopics_randomState2 = []

for m, cv in zip(range(start2, limit2, step2), coherence_values2):
    print("Num Topics =", m , "and Random Variable =", random_state2 , "has Coherence Value of", round(cv, 4))

    nrTopics_randomState2.append('nrTopics: ' + str(m) + ', randomState: ' + str(random_state2))
# Out:
# Num Topics = 8 and Random Variable = 4 has Coherence Value of 0.4392
# Num Topics = 9 and Random Variable = 4 has Coherence Value of 0.476
# Num Topics = 10 and Random Variable = 4 has Coherence Value of 0.4569
# Num Topics = 11 and Random Variable = 4 has Coherence Value of 0.4665
# Num Topics = 12 and Random Variable = 4 has Coherence Value of 0.4411
# Num Topics = 13 and Random Variable = 4 has Coherence Value of 0.4913
# Num Topics = 14 and Random Variable = 4 has Coherence Value of 0.4972
# Num Topics = 15 and Random Variable = 4 has Coherence Value of 0.4639
# Num Topics = 16 and Random Variable = 4 has Coherence Value of 0.466
# Num Topics = 17 and Random Variable = 4 has Coherence Value of 0.4579
# Num Topics = 18 and Random Variable = 4 has Coherence Value of 0.4631
# Num Topics = 19 and Random Variable = 4 has Coherence Value of 0.459
# Num Topics = 20 and Random Variable = 4 has Coherence Value of 0.4568
# Num Topics = 21 and Random Variable = 4 has Coherence Value of 0.4535
# Num Topics = 22 and Random Variable = 4 has Coherence Value of 0.447
# Num Topics = 23 and Random Variable = 4 has Coherence Value of 0.4458
# Num Topics = 24 and Random Variable = 4 has Coherence Value of 0.4651
# Num Topics = 25 and Random Variable = 4 has Coherence Value of 0.4474
# Num Topics = 26 and Random Variable = 4 has Coherence Value of 0.466
# Num Topics = 27 and Random Variable = 4 has Coherence Value of 0.4579
# Num Topics = 28 and Random Variable = 4 has Coherence Value of 0.4612
# Num Topics = 29 and Random Variable = 4 has Coherence Value of 0.4503

# %%
f = plt.figure(figsize=(12, 6), dpi=80)

coherencePlot(start2, limit2, step2, coherence_values2, f)

# %% [markdown]
# ### Result
# This gives us the 5 highest coherence values:

# %%
# Print top 5 best coherence values
i=1
for cv, name in sorted(zip(coherence_values2, nrTopics_randomState2), reverse=True)[:5]:
    print(str(i) + '. Coherence score:', round(cv, 3), name)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f1d4cb88e00c> in <module>
#       1 # Print top 5 best coherence values
#       2 i=1
# ----> 3 for cv, name in sorted(zip(coherence_values2, nrTopics_randomState2), reverse=True)[:5]:
#       4     print(str(i) + '. Coherence score:', round(cv, 3), name)
#       5     i+=1
#
# NameError: name 'coherence_values2' is not defined
